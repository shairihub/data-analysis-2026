# %% [markdown]
# <a href="https://colab.research.google.com/github/shairihub/data-analysis-2026/blob/main/Shairi_Project_1_redo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# I'm loading the data and setting up the graphs.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 20)
pd.set_option('display.float_format', lambda x: f"{x:,.2f}")

sns.set(style='whitegrid')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %% [markdown]
# I want to know what columns are present.

# %%
print(df.columns)
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %% [markdown]
# I want to see it in a clean table.

# %%
display(df)
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %% [markdown]
# I want to know how many rows and column exist on this table.

# %%
print(df.shape)
# Out:
# (212331, 15)

# %% [markdown]
# It's a lot of data so I only want to view the top 10 instead of over 200,000

# %%
df.head(11)
# Out:
#    School DBN                     School Name School Level  \
# 0      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3      01M140          P.S. 140 Nathan Straus          K-8
# 4      01M140          P.S. 140 Nathan Straus          K-8
# 5      01M140          P.S. 140 Nathan Straus          K-8
# 6      01M140          P.S. 140 Nathan Straus          K-8
# 7      01M140          P.S. 140 Nathan Straus          K-8
# 8      01M184            P.S. 184m Shuang Wen          K-8
# 9      01M184            P.S. 184m Shuang Wen          K-8
# 10     01M184            P.S. 184m Shuang Wen          K-8
#
#            Regents Exam  Year  Total Tested Mean Score  \
# 0   Common Core Algebra  2017             4          s
# 1    Living Environment  2015            16       77.9
# 2    Living Environment  2016             9         74
# ...

# %% [markdown]
# I want an easy way to copy and paste the columns for later so I print them. I also want to know what types of data I have since I think those "s" will cause an issue and I need to get rid of then later.

# %%
print(df.columns)
print(df.dtypes)
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')
# School DBN                     object
# School Name                    object
# School Level                   object
# Regents Exam                   object
# Year                            int64
# Total Tested                    int64
# Mean Score                     object
# Number Scoring Below 65        object
# Percent Scoring Below 65       object
# Number Scoring 65 or Above     object
# Percent Scoring 65 or Above    object
# Number Scoring 80 or Above     object
# Percent Scoring 80 or Above    object
# Number Scoring CR              object
# Percent Scoring CR             object
# ...

# %% [markdown]
# I want a cleaner table with only the data that I want to examine so I drop some columns.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')
drop_columns = ['School DBN', 'Mean Score', 'Number Scoring 65 or Above',
                'Number Scoring Below 65', 'Number Scoring 80 or Above',
                'Percent Scoring 65 or Above', 'Number Scoring CR',
                'Percent Scoring CR']
display(df.drop(columns=drop_columns))
# Out:
#                            School Name School Level  \
# 0       P.S. 034 Franklin D. Roosevelt          K-8
# 1       P.S. 034 Franklin D. Roosevelt          K-8
# 2       P.S. 034 Franklin D. Roosevelt          K-8
# 3               P.S. 140 Nathan Straus          K-8
# 4               P.S. 140 Nathan Straus          K-8
# ...                                ...          ...
# 212326            Icahn Charter School          K-8
# 212327            Icahn Charter School          K-8
# 212328            Icahn Charter School          K-8
# 212329            Icahn Charter School          K-8
# 212330            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested  \
# 0               Common Core Algebra  2017             4
# 1                Living Environment  2015            16
# 2                Living Environment  2016             9
# 3               Common Core Algebra  2016             3
# ...

# %% [markdown]
# I test out describe and find that some of the columns are being interpreted weirdly. Years should not be read this way. I dig in to find out how to fix it.

# %%
df.describe()
# Out:
#             Year  Total Tested
# count 212,331.00    212,331.00
# mean    2,015.96         49.36
# std         0.80         93.02
# min     2,015.00          1.00
# 25%     2,015.00          5.00
# 50%     2,016.00         20.00
# 75%     2,017.00         57.00
# max     2,017.00      1,729.00

# %% [markdown]
# I want to change out some objects to categories, floats, and intergers for easier data handling. In my original file, not changing these caused errors and issues. I did some research and updated the data types but also used some help from AI to fix errors that I could not figure out and also had it explain to me what the issue with the code was.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

categorical_cols = ['School Name', 'School Level', 'Regents Exam', 'Year']

for c in categorical_cols:
    df[c] = df[c].astype('category')

df['Percent Scoring 80 or Above'] = pd.to_numeric(df['Percent Scoring 80 or Above'], errors='coerce')

df['Percent Scoring Below 65'] = pd.to_numeric(df['Percent Scoring Below 65'], errors='coerce')

drop_columns = ['School DBN', 'Mean Score', 'Number Scoring 65 or Above',
                'Number Scoring Below 65', 'Number Scoring 80 or Above',
                'Percent Scoring 65 or Above', 'Number Scoring CR',
                'Percent Scoring CR']

df = df.drop(columns=drop_columns)

print(df.dtypes)
# Out:
# School Name                    category
# School Level                   category
# Regents Exam                   category
# Year                           category
# Total Tested                      int64
# Percent Scoring Below 65        float64
# Percent Scoring 80 or Above     float64
# dtype: object

# %% [markdown]
# I just want to see that the previous columns were dropped for easier copy pasting in the future.

# %%
print(df.columns)
# Out:
# Index(['School Name', 'School Level', 'Regents Exam', 'Year', 'Total Tested',
#        'Percent Scoring Below 65', 'Percent Scoring 80 or Above'],
#       dtype='object')

# %% [markdown]
# I was unsure what those "s" were but I knew they would cause issues since they don't appear to be numbers. I find out that they are suppressed data. I decide to convert them to numerical figures after getting many errors in previous attempts at working with them.

# %%
df = df[df['Percent Scoring 80 or Above'] != 's']
df = df[df['Percent Scoring Below 65'] != 's']
display(df)
# Out:
#                            School Name School Level  \
# 0       P.S. 034 Franklin D. Roosevelt          K-8
# 1       P.S. 034 Franklin D. Roosevelt          K-8
# 2       P.S. 034 Franklin D. Roosevelt          K-8
# 3               P.S. 140 Nathan Straus          K-8
# 4               P.S. 140 Nathan Straus          K-8
# ...                                ...          ...
# 212326            Icahn Charter School          K-8
# 212327            Icahn Charter School          K-8
# 212328            Icahn Charter School          K-8
# 212329            Icahn Charter School          K-8
# 212330            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested  \
# 0               Common Core Algebra  2017             4
# 1                Living Environment  2015            16
# 2                Living Environment  2016             9
# 3               Common Core Algebra  2016             3
# ...

# %% [markdown]
# I get rid of the NaN items for cleaner viewing

# %%
df = df.dropna()
df.head(11)
# Out:
#                        School Name School Level         Regents Exam  Year  \
# 1   P.S. 034 Franklin D. Roosevelt          K-8   Living Environment  2015
# 2   P.S. 034 Franklin D. Roosevelt          K-8   Living Environment  2016
# 5           P.S. 140 Nathan Straus          K-8   Living Environment  2015
# 6           P.S. 140 Nathan Straus          K-8   Living Environment  2016
# 7           P.S. 140 Nathan Straus          K-8   Living Environment  2017
# 8             P.S. 184m Shuang Wen          K-8  Common Core Algebra  2015
# 9             P.S. 184m Shuang Wen          K-8  Common Core Algebra  2016
# 10            P.S. 184m Shuang Wen          K-8  Common Core Algebra  2017
# 11            P.S. 184m Shuang Wen          K-8   Living Environment  2017
# 12      P.S. 188 The Island School          K-8  Common Core Algebra  2015
# 13      P.S. 188 The Island School          K-8  Common Core Algebra  2016
#
# ...

# %% [markdown]
# I wanted to know the name of the regents exams and I though that this would work but...

# %%
df['Regents Exam']
# Out:
# 1          Living Environment
# 2          Living Environment
# 5          Living Environment
# 6          Living Environment
# 7          Living Environment
#                  ...
# 212321    Common Core Algebra
# 212322    Common Core Algebra
# 212323    Common Core Algebra
# 212324     Living Environment
# 212325     Living Environment
# Name: Regents Exam, Length: 137101, dtype: category
# Categories (14, object): ['Algebra2/Trigonometry', 'Common Core Algebra', 'Common Core Algebra2',
#                           'Common Core English', ..., 'Physical Settings/Chemistry',
#                           'Physical Settings/Earth Science', 'Physical Settings/Physics',
#                           'U.S. History and Government']

# %% [markdown]
# There's too many rows for that to be effective.
#
# I decided that a different print function would be better.

# %%
print(df['Regents Exam'].cat.categories)
print(df['School Name'].cat.categories)
# Out:
# Index(['Algebra2/Trigonometry', 'Common Core Algebra', 'Common Core Algebra2',
#        'Common Core English', 'Common Core Geometry', 'English', 'Geometry',
#        'Global History and Geography', 'Integrated Algebra',
#        'Living Environment', 'Physical Settings/Chemistry',
#        'Physical Settings/Earth Science', 'Physical Settings/Physics',
#        'U.S. History and Government'],
#       dtype='object')
# Index(['47 The American Sign Language and English Secondar',
#        'A. Philip Randolph Campus High School', 'ACORN Community High School',
#        'Abraham Lincoln High School', 'Abraham Lincoln Yabc',
#        'Academy For Personal Leadership And Excellence',
#        'Academy for Careers in Television and Film',
#        'Academy for College Preparation and Career Explora',
#        'Academy for Conservation and the Environment',
#        'Academy for Environmental Leadership',
#        ...
#        'World Academy for Total Community Health High Scho',
# ...

# %% [markdown]
# I want to display graphs that show the amount of student scoring below 65 (fail) vs the amount of students scoring above 80 (highest grades). How many students are doing outstanding vs how many are not passing and need improvement in certian areas?

# %%
ffig, axes = plt.subplots(1, 2, figsize=(10, 5))

sns.histplot(df['Percent Scoring Below 65'], bins=11, kde=True, ax=axes[0])
axes[0].set_title('Students Scoring Below 65')

sns.histplot(df['Percent Scoring 80 or Above'], bins=11, kde=True, ax=axes[1])
axes[1].set_title('Students Scoring 80 or Above')

plt.tight_layout()
plt.show()

# %% [markdown]
# The assignment said to pick one school to compare so now I want to find out how to compare the stats common core english in ACORN Community High School vs. Academy for Conservation and the Environment.
#
#  Below are my attempts at filtering the data.

# %%
Exam = df[['Regents Exam', 'School Name', 'Year']]
display(Exam)
# Out:
#                Regents Exam                     School Name  Year
# 1        Living Environment  P.S. 034 Franklin D. Roosevelt  2015
# 2        Living Environment  P.S. 034 Franklin D. Roosevelt  2016
# 5        Living Environment          P.S. 140 Nathan Straus  2015
# 6        Living Environment          P.S. 140 Nathan Straus  2016
# 7        Living Environment          P.S. 140 Nathan Straus  2017
# ...                     ...                             ...   ...
# 212321  Common Core Algebra            Icahn Charter School  2016
# 212322  Common Core Algebra            Icahn Charter School  2017
# 212323  Common Core Algebra            Icahn Charter School  2017
# 212324   Living Environment            Icahn Charter School  2015
# 212325   Living Environment            Icahn Charter School  2015
#
# [137101 rows x 3 columns]

# %%
Schools_filtered = ['ACORN Community High School', 'Academy for Conservation and the Environment']
Years_filtered = ['2015', '2016']
filtered_exam = Exam[Exam['School Name'].isin(Schools_filtered)]
display(filtered_exam)
# Out:
#                        Regents Exam  \
# 8657          Algebra2/Trigonometry
# 8658          Algebra2/Trigonometry
# 8659            Common Core Algebra
# 8660            Common Core Algebra
# 8661            Common Core Algebra
# ...                             ...
# 181629  U.S. History and Government
# 181631  U.S. History and Government
# 181632  U.S. History and Government
# 181633  U.S. History and Government
# 181634  U.S. History and Government
#
#                                          School Name  Year
# 8657                     ACORN Community High School  2015
# 8658                     ACORN Community High School  2016
# 8659                     ACORN Community High School  2015
# 8660                     ACORN Community High School  2016
# 8661                     ACORN Community High School  2017
# ...                                              ...   ...
# 181629  Academy for Conservation and the Environment  2016
# ...

# %%
filtered_exam = filtered_exam[filtered_exam['Year'].isin([2015, 2016])]
display(filtered_exam)
# Out:
#                        Regents Exam  \
# 8657          Algebra2/Trigonometry
# 8658          Algebra2/Trigonometry
# 8659            Common Core Algebra
# 8660            Common Core Algebra
# 8664            Common Core English
# ...                             ...
# 181623  U.S. History and Government
# 181624  U.S. History and Government
# 181628  U.S. History and Government
# 181629  U.S. History and Government
# 181631  U.S. History and Government
#
#                                          School Name  Year
# 8657                     ACORN Community High School  2015
# 8658                     ACORN Community High School  2016
# 8659                     ACORN Community High School  2015
# 8660                     ACORN Community High School  2016
# 8664                     ACORN Community High School  2015
# ...                                              ...   ...
# 181623  Academy for Conservation and the Environment  2015
# ...

# %%
filtered_exam = filtered_exam[filtered_exam['Regents Exam'] == 'Common Core English']
display(filtered_exam)
# Out:
#                Regents Exam                                   School Name  \
# 8664    Common Core English                   ACORN Community High School
# 8665    Common Core English                   ACORN Community High School
# 11343   Common Core English  Academy for Conservation and the Environment
# 11344   Common Core English  Academy for Conservation and the Environment
# 35078   Common Core English                   ACORN Community High School
# ...                     ...                                           ...
# 172253  Common Core English                   ACORN Community High School
# 181534  Common Core English  Academy for Conservation and the Environment
# 181535  Common Core English  Academy for Conservation and the Environment
# 181539  Common Core English  Academy for Conservation and the Environment
# 181540  Common Core English  Academy for Conservation and the Environment
#
#         Year
# 8664    2015
# 8665    2016
# 11343   2015
# 11344   2016
# ...

# %% [markdown]
# I originally was going to compare data from 2015 and 2016 but decided to keep it simple and just do 2015.

# %%
schools_to_plot = ['ACORN Community High School', 'Academy for Conservation and the Environment']
years_to_plot = [2015]

filtered_data_for_plot = df[
    (df['Regents Exam'] == 'Common Core English') &
    (df['School Name'].isin(schools_to_plot)) &
    (df['Year'].isin(years_to_plot))
]

ffig, axes = plt.subplots(1, 2, figsize=(12, 6))

sns.histplot(filtered_data_for_plot['Percent Scoring Below 65'], bins=11, kde=True, ax=axes[0])
axes[0].set_title('Common Core English: Percent Scoring Below 65')
axes[0].set_xlabel('Percent Below 65')
axes[0].set_ylabel('Frequency')

sns.histplot(filtered_data_for_plot['Percent Scoring 80 or Above'], bins=11, kde=True, ax=axes[1])
axes[1].set_title('Common Core English: Percent Scoring 80 or Above')
axes[1].set_xlabel('Percent 80 or Above')
axes[1].set_ylabel('Frequency')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# When we examine the english score list closer we can see that the most frequent results were around 20 percent of students scored below 65 in english and 25 percent of students scored above 80.
